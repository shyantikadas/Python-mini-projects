# %% [markdown]
# # Python Projects practice

# %% [markdown]
# ## Rock paper scissors game

# %%
from random import randint

l = ['Rock', 'Paper','Scissors']
computer = l[randint(0,2)]
player=False
while player == False:
    player=input('Rock, Paper, Scissors?')
    
    if player == computer:
        print("It's a tie!")
    elif player == 'Rock':
        if computer == 'Paper':
            print('You lose!')
        else:
            print('You Win!')
    elif player == 'Paper':
        if computer == 'Scissors':
            print('You lose!')
        else:
            print('You Win!')
    elif player == 'Scissors':
        if computer == 'Rock':
            print('You lose!')
        else:
            print('You Win!')
    else:
        print('Invalid!')
    
    player = False #we reset the player value to false as when the game starts the player value automatically sets to True, so we need to assign it to false again to get the while loop started again and continue the game
    computer = l[randint(0,2)]
# Out:
# Rock, Paper, Scissors?Rock
# It's a tie!
# Rock, Paper, Scissors?Rock
# You Win!
# Rock, Paper, Scissors?Paper
# It's a tie!
# Rock, Paper, Scissors?Scissors
# It's a tie!
# Rock, Paper, Scissors?Paper
# You Win!
# Rock, Paper, Scissors?Paper
# You Win!
# Rock, Paper, Scissors?Paper
# It's a tie!
# Rock, Paper, Scissors?Scissors
# You lose!
# Rock, Paper, Scissors?
# Invalid!
# Rock, Paper, Scissors?Rock
# You lose!

# %% [markdown]
# # Guessing game

# %%
import random
number = random.randint(1,20)
name = input('What is your name? ')
print('Alright!', name, 'Lets start the game, I am guessing a number between 1 to 20. ')
number_of_guesses = 0

while number_of_guesses < 5:
    guess = int(input('Guess my number?'))
    number_of_guesses += 1
    if guess < number:
        print('Your guessed number is way too low!')
    if guess > number:
        print('Your guessed number is way too high!')
    if guess == number:
        break
if guess == number:
    print('Congratulations! You guessed the right number in', str(number_of_guesses),'tries!')
else:
    print('Sorry :( , you could not guess the right number. The number was', str(number), '. Better luck next time!')

# %% [markdown]
# # Mad libs

# %%
#Taking the inputs from the user first
print("Let's play MAD LIBS!")
organ = input('Enter the name of a body part: ')
adjective = input('Enter an adjective: ')
noun = input('Enter a noun: ')
print('After hiding the painting in his', '|', organ,'|', 'for two years, he grew','|', adjective,'|','and tried to sell it to a/an','|',noun,'|','in Florida. But got caugth!')
print('Hahaha! It was really fun.')
# Out:
# Let's play MAD LIBS!
# Enter the name of a body part: eyes
# Enter an adjective: happy
# Enter a noun: mug
# After hiding the painting in his | eyes | for two years, he grew | happy | and tried to sell it to a/an | mug | in Florida. But got caugth!
# Hahaha! It was really fun.

# %% [markdown]
# # HANGMAN game

# %% [markdown]
# Pseudo code
# 1. Total number of turns the player gets : 6
# 2. guess the word
# 3. check the guessed word
# 4. if wrongly guessed then increase the counts
# 5. print the correctly guessed letters
# 6. if guessed then break

# %%
import random
import words # created a library containing different words
from words import word_list


def get_word():
    word = random.choice(word_list)
    return word.upper()


def play(word):
    word_completion = "_" * len(word)
    guessed = False
    guessed_letters = []
    guessed_words = []
    tries = 6
    print("Let's play Hangman!")
    print(display_hangman(tries))
    print(word_completion)
    print("\n")
    while not guessed and tries > 0:
        guess = input("Please guess a letter or word: ").upper()
        if len(guess) == 1 and guess.isalpha():
            if guess in guessed_letters:
                print("You already guessed the letter", guess)
            elif guess not in word:
                print(guess, "is not in the word.")
                tries -= 1
                guessed_letters.append(guess)
            else:
                print("Good job,", guess, "is in the word!")
                guessed_letters.append(guess)
                word_as_list = list(word_completion)
                indices = [i for i, letter in enumerate(word) if letter == guess]
                for index in indices:
                    word_as_list[index] = guess
                word_completion = "".join(word_as_list)
                if "_" not in word_completion:
                    guessed = True
        elif len(guess) == len(word) and guess.isalpha():
            if guess in guessed_words:
                print("You already guessed the word", guess)
            elif guess != word:
                print(guess, "is not the word.")
                tries -= 1
                guessed_words.append(guess)
            else:
                guessed = True
                word_completion = word
        else:
            print("Not a valid guess.")
        print(display_hangman(tries))
        print(word_completion)
        print("\n")
    if guessed:
        print("Congrats, you guessed the word! You win!")
    else:
        print("Sorry, you ran out of tries. The word was " + word + ". Maybe next time!")


def display_hangman(tries):
    stages = [  # final state: head, torso, both arms, and both legs
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                   -
                """,
                # head, torso, both arms, and one leg
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / 
                   -
                """,
                # head, torso, and both arms
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |      
                   -
                """,
                # head, torso, and one arm
                """
                   --------
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |     
                   -
                """,
                # head and torso
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |     
                   -
                """,
                # head
                """
                   --------
                   |      |
                   |      O
                   |    
                   |      
                   |     
                   -
                """,
                # initial empty state
                """
                   --------
                   |      |
                   |      
                   |    
                   |      
                   |     
                   -
                """
    ]
    return stages[tries]


def main():
    word = get_word()
    play(word)
    while input("Play Again? (Y/N) ").upper() == "Y":
        word = get_word()
        play(word)


if __name__ == "__main__":
    main()
# Out:
# Let's play Hangman!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# ____
#
#
# Please guess a letter or word: b
# B is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# ____
#
#
# Please guess a letter or word: c
# Good job, C is in the word!
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# C___
#
#
# Please guess a letter or word: l
# Good job, L is in the word!
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# CL__
#
#
# ...
